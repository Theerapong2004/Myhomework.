# %%
for i in range (1, 6):
    print(' * ' * i)
    
for i in range (0, 0, -1):
    print(' * ' * i)
# Out:
#  *
#  *  *
#  *  *  *
#  *  *  *  *
#  *  *  *  *  *

# %%
for i in range (5, 0, -1):
    print(' * ' * i)
# Out:
#  *  *  *  *  *
#  *  *  *  *
#  *  *  *
#  *  *
#  *

# %%
num = 6
end = num - 1
for i in range(0, num):
    for j in range(0, num):
        if j >= end - i:
            print(" *", end="")
        else:
            print("  ", end="")
    print()
# Out:
#            *
#          * *
#        * * *
#      * * * *
#    * * * * *
#  * * * * * *
